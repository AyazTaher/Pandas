# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## Pandas Course الدرس الأول 1
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## قراءة الملفات واستكشاف البيانات باستخدام Pandas
#
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# #### تنصيب مكتبة Pandas

# %%
# pip install pandas

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#  استيراد المكتبة
#  </div>

# %%
import pandas as pd

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### 1- قراءة ملفات  CSV
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
#  </div>

# %%
df1 = pd.read_csv(r"D:\Pandas\Pandas_Course\countries of the world.csv")

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 1.1 عرض البيانات مع تحديد عدد الصفوف
#
#  </div>

# %%
df1.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 1.2 عرض بيانات الملفات التي لا تحتوي على اسماء الأعمدة
#
#  </div>

# %%
df1 = pd.read_csv(r"D:\Pandas\Pandas_Course\without_header_name.csv",
    sep = ';',
    header = None,
    names = ['ID_Code', 'Age', 'Status', 'Reagon', 'Score', 'Year'],)


df1.head()
# Out:
#   ID_Code  Age Status Reagon  Score  Year
# 0     A12   45    Yes  North    3.5  2024
# 1     B09   33     No   East    2.1  2023
# 2     C88   27    Yes  South    4.0  2025
# 3     D77   52     No   West    1.9  2022
# 4     E41   29    Yes  North    3.2  2024

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### 2- قراءة الملفات بشكل عام مع تحديد الفاصلة
#  </div>

# %%
df2 = pd.read_table(r"D:\Pandas\Pandas_Course\syria_data.txt", sep= ';')

df2.head()
# Out:
#    ID     Name  Age  Grade      City Country
# 0   1      Ali   15     10  Damascus   Syria
# 1   2     Sara   14      9    Aleppo   Syria
# 2   3     Omar   16     11      Homs   Syria
# 3   4     Lina   15     10   Latakia   Syria
# 4   5  Youssef   14      9      Hama   Syria

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 3- قراءة ملفات JSON
#
# </div>

# %%
df3 = pd.read_json(r"D:\Pandas\Pandas_Course\json_sample.json")
df3
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4- قراءة ملفات Excel
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4.1. بدون تحديد اسم الصفحة
#  </div>

# %%
df4 = pd.read_excel(r"D:\Pandas\Pandas_Course\world_population1.xlsx")
df4.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4.2. مع تحديد اسم الصفحة
#  </div>

# %%
df4 = pd.read_excel(r"D:\Pandas\Pandas_Course\world_population2.xlsx", sheet_name = 'Sheet1')
df4.head()
# Out:
#    Rank CCA3         Country           Capital
# 0    36  AFG     Afghanistan             Kabul
# 1   138  ALB         Albania            Tirana
# 2    34  DZA         Algeria           Algiers
# 3   213  ASM  American Samoa         Pago Pago
# 4   203  AND         Andorra  Andorra la Vella

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4.3. التعامل مع الصفوف الفارغة في الأعلى
#  </div>

# %%
df4 = pd.read_excel(r"D:\Pandas\Pandas_Course\world_population3.xlsx")
df4.head(12)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4      Unnamed: 5  \
# 0          NaN         NaN         NaN        NaN        NaN             NaN
# 1          NaN         NaN         NaN        NaN        NaN             NaN
# 2          NaN         NaN         NaN        NaN        NaN             NaN
# 3          NaN         NaN         NaN        NaN        NaN             NaN
# 4          NaN         NaN         NaN        NaN        NaN             NaN
# 5          NaN         NaN         NaN       Rank       CCA3         Country
# 6          NaN         NaN         NaN         36        AFG     Afghanistan
# 7          NaN         NaN         NaN        138        ALB         Albania
# 8          NaN         NaN         NaN         34        DZA         Algeria
# 9          NaN         NaN         NaN        213        ASM  American Samoa
# 10         NaN         NaN         NaN        203        AND         Andorra
# ...

# %%
df4 = pd.read_excel(r"D:\Pandas\Pandas_Course\world_population3.xlsx", skiprows =6)
df4.head(12)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Rank CCA3              Country  \
# 0          NaN         NaN         NaN    36  AFG          Afghanistan
# 1          NaN         NaN         NaN   138  ALB              Albania
# 2          NaN         NaN         NaN    34  DZA              Algeria
# 3          NaN         NaN         NaN   213  ASM       American Samoa
# 4          NaN         NaN         NaN   203  AND              Andorra
# 5          NaN         NaN         NaN    42  AGO               Angola
# 6          NaN         NaN         NaN   224  AIA             Anguilla
# 7          NaN         NaN         NaN   201  ATG  Antigua and Barbuda
# 8          NaN         NaN         NaN    33  ARG            Argentina
# 9          NaN         NaN         NaN   140  ARM              Armenia
# 10         NaN         NaN         NaN   198  ABW                Aruba
# 11         NaN         NaN         NaN    55  AUS            Australia
#
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4.4. التعامل مع الصفوف الفارغة في اليسار- الطريقة الأولى
#   </div>

# %%
df4 = pd.read_excel(r"D:\Pandas\Pandas_Course\world_population3.xlsx", skiprows =6, usecols='D:T')
df4.head(12)
# Out:
#     Rank CCA3              Country           Capital      Continent  \
# 0     36  AFG          Afghanistan             Kabul           Asia
# 1    138  ALB              Albania            Tirana         Europe
# 2     34  DZA              Algeria           Algiers         Africa
# 3    213  ASM       American Samoa         Pago Pago        Oceania
# 4    203  AND              Andorra  Andorra la Vella         Europe
# 5     42  AGO               Angola            Luanda         Africa
# 6    224  AIA             Anguilla        The Valley  North America
# 7    201  ATG  Antigua and Barbuda    Saint Johnâ€™s  North America
# 8     33  ARG            Argentina      Buenos Aires  South America
# 9    140  ARM              Armenia           Yerevan           Asia
# 10   198  ABW                Aruba        Oranjestad  North America
# 11    55  AUS            Australia          Canberra        Oceania
#
#     2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4.4. التعامل مع الصفوف الفارغة في اليسار- الطريقة الثانية
#   </div>

# %%
df5 = pd.read_excel(r"D:\Pandas\Pandas_Course\world_population3.xlsx", skiprows=6)
df5 = df5.dropna(axis=1, how = 'all')
df5.head(10)
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 5- قراءة ملفات SQL
#  </div>

# %%
import sqlite3

db_path = r"D:\Pandas\Pandas_Course\Chinook_Sqlite.sqlite"
conn = sqlite3.connect(db_path)
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type = 'table';", conn)
print(tables)

df_sql_cusstomer = pd.read_sql("SELECT * FROM Customer", conn)
print(df_sql_cusstomer)
# Out:
#              name
# 0           Album
# 1          Artist
# 2        Customer
# 3        Employee
# 4           Genre
# 5         Invoice
# 6     InvoiceLine
# 7       MediaType
# 8        Playlist
# 9   PlaylistTrack
# 10          Track
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6- قراءة البيانات من Clipboard
#  </div>

# %%
df_clip = pd.read_clipboard()
print(df_clip)
# Out:
#     CustomerId  FirstName   LastName            \
# 0            0          1       Luís    Gonçalves
# 1            1          2     Leonie       Köhler
# 2            2          3   François     Tremblay
# 3            3          4      Bjørn       Hansen
# 4            4          5  František  Wichterlová
# 5            5          6     Helena         Holý
# 6            6          7     Astrid       Gruber
# 7            7          8       Daan      Peeters
# 8            8          9       Kara      Nielsen
# 9            9         10    Eduardo      Martins
# 10          10         11  Alexandre        Rocha
# 11          11         12    Roberto      Almeida

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 7- قراءة جداول HTML مباشرة من الويب
#  </div>

# %%
# pip install requests

# %%
import requests
from io import StringIO
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers= headers)
html = response.text

dfs = pd.read_html(StringIO(html))

print("Tables Number", len(dfs))
# Out:
# Tables Number 3

# %%
df_population = dfs[0]
df_population.head(20)
# Out:
#                             Location  Population % of world         Date  \
# 0                              World  8232000000       100%  13 Jun 2025
# 1                              India  1417492000      17.2%   1 Jul 2025
# 2                              China  1404890000      17.0%  31 Dec 2025
# 3                      United States   341784857       4.1%   1 Jul 2025
# 4                          Indonesia   288315089       3.5%  31 Dec 2025
# 5                           Pakistan   241499431       2.9%   1 Mar 2023
# 6                            Nigeria   223800000       2.7%   1 Jul 2023
# 7                             Brazil   213421037       2.6%   1 Jul 2025
# 8                         Bangladesh   169828911       2.1%  14 Jun 2022
# 9                             Russia   146028325       1.8%   1 Jan 2025
# 10                            Mexico   131001723       1.6%  31 Dec 2025
# 11                             Japan   122850000       1.5%   1 Mar 2026
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 8. استكشاف البيانات
#
#
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 8.1 معرفة اسماء الاعمدة
#
#  </div>

# %%
df5.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (kmÂ²)', 'Density (per kmÂ²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %% [markdown]
#  <div dir="rtl" style="text-align: right;">
# 8.2 معرفة حجم البيانات عدد الصفوف والأعمدة
#
#  </div>

# %%
df5.shape
# Out:
# (234, 17)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 8.3 عرض معلومات هيكلية عن البيانات
#
#
#  </div>

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.4 معرفة نوع البيانات لكل عمود
#
# </div>

# %%
df5.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (kmÂ²)                      int64
# Density (per kmÂ²)             float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.5 الإحصائيات الوصفية للأعمدة الرقمية
#
#  </div>

# %%
df5.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.6 معاينة أول عدة صفوف من البيانات
#
#  </div>

# %%
df5.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 8.7 معاينة آخر عدد من الصفوف
#
#  </div>

# %%
df5.tail()
# Out:
#      Rank CCA3            Country    Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna   Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El AaiÃºn    Africa           575986
# 231    46  YEM              Yemen      Sanaa      Asia         33696614
# 232    63  ZMB             Zambia     Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe     Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 8.8 أخذ عينة عشوائية من البيانات
#
#  </div>

# %%
df5.sample(20)
# Out:
#      Rank CCA3        Country       Capital      Continent  2022 Population  \
# 44    223  COK   Cook Islands        Avarua        Oceania            17011
# 110   103  LAO           Laos     Vientiane           Asia          7529475
# 12     99  AUT        Austria        Vienna         Europe          8939617
# 26    144  BWA       Botswana      Gaborone         Africa          2630296
# 194    29  KOR    South Korea         Seoul           Asia         51815810
# 62    159  SWZ       Eswatini       Mbabane         Africa          1201670
# 40     65  CHL          Chile      Santiago  South America         19603733
# 69    184  GUF  French Guiana       Cayenne  South America           304557
# 73    131  GEO        Georgia       Tbilisi           Asia          3744385
# 180   218  SMR     San Marino    San Marino         Europe            33660
# 43    163  COM        Comoros        Moroni         Africa           836774
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.9 معاينة  قيم عمود محدد
#
#  </div>

# %%
df5['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.10 الكشف عن القيم الفارغة
#  </div>

# %%
df5.isnull()
# Out:
#       Rank   CCA3  Country  Capital  Continent  2022 Population  \
# 0    False  False    False    False      False            False
# 1    False  False    False    False      False            False
# 2    False  False    False    False      False            False
# 3    False  False    False    False      False            False
# 4    False  False    False    False      False            False
# ..     ...    ...      ...      ...        ...              ...
# 229  False  False    False    False      False            False
# 230  False  False    False    False      False            False
# 231  False  False    False    False      False            False
# 232  False  False    False    False      False            False
# 233  False  False    False    False      False            False
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 0              False            False            False            False
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.11 الكشف عن عدد القيم الفارغة ضمن كل عمود
#
# </div>

# %%
df5.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (kmÂ²)                    0
# Density (per kmÂ²)             0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 8.12 القيم الفريدة لكل عمود
#
# </div>

# %%
df5.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (kmÂ²)                    233
# Density (per kmÂ²)             234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64
