# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## Pandas Course الدرس الثاني 2
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## Indexing الفهرسة
#
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 0. استيراد المكتبة
#
#
#  </div>

# %%
import pandas as pd

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 1. قراءة الملف
#
#  </div>

# %%
df = pd.read_csv(r"D:\Pandas\Pandas_Course\world_population.csv")
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent       Average  \
# 0    36  AFG     Afghanistan             Kabul      Asia  2.444019e+07
# 1   138  ALB         Albania            Tirana    Europe  2.906065e+06
# 2    34  DZA         Algeria           Algiers    Africa  3.157280e+07
# 3   213  ASM  American Samoa         Pago Pago   Oceania  4.533600e+04
# 4   203  AND         Andorra  Andorra la Vella    Europe  5.949075e+04
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# 2       44903225.0       43451666.0       39543154.0       35856344.0
# 3          44273.0          46189.0          51368.0          54849.0
# 4          79824.0          77700.0          71746.0          71519.0
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 2. قراءة الملف مع تحديد عمود الفهرسة مباشراً
#
#  </div>

# %%
df = pd.read_csv(r"D:\Pandas\Pandas_Course\world_population.csv", index_col='Country')
df.head()
# Out:
#                 Rank CCA3           Capital Continent       Average  \
# Country
# Afghanistan       36  AFG             Kabul      Asia  2.444019e+07
# Albania          138  ALB            Tirana    Europe  2.906065e+06
# Algeria           34  DZA           Algiers    Africa  3.157280e+07
# American Samoa   213  ASM         Pago Pago   Oceania  4.533600e+04
# Andorra          203  AND  Andorra la Vella    Europe  5.949075e+04
#
#                 2022 Population  2020 Population  2015 Population  \
# Country
# Afghanistan          41128771.0       38972230.0       33753499.0
# Albania               2842321.0        2866849.0        2882481.0
# Algeria              44903225.0       43451666.0       39543154.0
# American Samoa          44273.0          46189.0          51368.0
# Andorra                 79824.0          77700.0          71746.0
#
#                 2010 Population  2000 Population  1990 Population  \
# Country
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# إعادة الفهرس إلى العمود الإفتراضي مع الإبقاء على الفهرس القديم
#  </div>

# %%
df.reset_index(drop=False, inplace=True)

df.head(10)
# Out:
#                Country  Rank CCA3           Capital      Continent  \
# 0          Afghanistan    36  AFG             Kabul           Asia
# 1              Albania   138  ALB            Tirana         Europe
# 2              Algeria    34  DZA           Algiers         Africa
# 3       American Samoa   213  ASM         Pago Pago        Oceania
# 4              Andorra   203  AND  Andorra la Vella         Europe
# 5               Angola    42  AGO            Luanda         Africa
# 6             Anguilla   224  AIA        The Valley  North America
# 7  Antigua and Barbuda   201  ATG      Saint John’s  North America
# 8            Argentina    33  ARG      Buenos Aires  South America
# 9              Armenia   140  ARM           Yerevan           Asia
#
#         Average  2022 Population  2020 Population  2015 Population  \
# 0  2.444019e+07       41128771.0       38972230.0       33753499.0
# 1  2.906065e+06        2842321.0        2866849.0        2882481.0
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4. استخدام set_index لتغيير الفهرس الإفتراضي و تعيين فهرس جديد
#
#  </div>

# %%
df.set_index("Country", inplace=True)
df.head(10)
# Out:
#                      Rank CCA3           Capital      Continent       Average  \
# Country
# Afghanistan            36  AFG             Kabul           Asia  2.444019e+07
# Albania               138  ALB            Tirana         Europe  2.906065e+06
# Algeria                34  DZA           Algiers         Africa  3.157280e+07
# American Samoa        213  ASM         Pago Pago        Oceania  4.533600e+04
# Andorra               203  AND  Andorra la Vella         Europe  5.949075e+04
# Angola                 42  AGO            Luanda         Africa  2.038648e+07
# Anguilla              224  AIA        The Valley  North America  1.141812e+04
# Antigua and Barbuda   201  ATG      Saint John’s  North America  7.873125e+04
# Argentina              33  ARG      Buenos Aires  South America  3.705995e+07
# Armenia               140  ARM           Yerevan           Asia  2.975691e+06
#
#                      2022 Population  2020 Population  2015 Population  \
# Country
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# إعادة الفهرس إلى العمود الإفتراضي
#  </div>

# %%
df.reset_index(inplace= True)
df.head()
# Out:
#           Country  Rank CCA3           Capital Continent       Average  \
# 0     Afghanistan    36  AFG             Kabul      Asia  2.444019e+07
# 1         Albania   138  ALB            Tirana    Europe  2.906065e+06
# 2         Algeria    34  DZA           Algiers    Africa  3.157280e+07
# 3  American Samoa   213  ASM         Pago Pago   Oceania  4.533600e+04
# 4         Andorra   203  AND  Andorra la Vella    Europe  5.949075e+04
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# 2       44903225.0       43451666.0       39543154.0       35856344.0
# 3          44273.0          46189.0          51368.0          54849.0
# 4          79824.0          77700.0          71746.0          71519.0
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 4. الفهرسة المركبة: اي جعل اكثر من عمود فهرساً
#  </div>

# %%
df.set_index(['Continent', 'Country'], inplace=True)

df.head()
# Out:
#                           Rank CCA3           Capital       Average  \
# Continent Country
# Asia      Afghanistan       36  AFG             Kabul  2.444019e+07
# Europe    Albania          138  ALB            Tirana  2.906065e+06
# Africa    Algeria           34  DZA           Algiers  3.157280e+07
# Oceania   American Samoa   213  ASM         Pago Pago  4.533600e+04
# Europe    Andorra          203  AND  Andorra la Vella  5.949075e+04
#
#                           2022 Population  2020 Population  2015 Population  \
# Continent Country
# Asia      Afghanistan          41128771.0       38972230.0       33753499.0
# Europe    Albania               2842321.0        2866849.0        2882481.0
# Africa    Algeria              44903225.0       43451666.0       39543154.0
# Oceania   American Samoa          44273.0          46189.0          51368.0
# Europe    Andorra                 79824.0          77700.0          71746.0
#
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 5. فرز الصفوف حسب الفهرس
#
#  </div>

# %%
df.sort_index()
# Out:
#                             Rank CCA3      Capital       Average  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers  3.157280e+07
#               Angola          42  AGO       Luanda  2.038648e+07
#               Benin           77  BEN   Porto-Novo  8.170413e+06
#               Botswana       144  BWA     Gaborone  1.771602e+06
#               Burkina Faso    58  BFA  Ouagadougou  1.407377e+07
# ...                          ...  ...          ...           ...
# South America Paraguay       109  PRY     Asunción  5.002089e+06
#               Peru            44  PER         Lima  2.588926e+07
#               Suriname       170  SUR   Paramaribo  4.991805e+05
#               Uruguay        133  URY   Montevideo  3.220075e+06
#               Venezuela       51  VEN      Caracas  2.319334e+07
#
#                             2022 Population  2020 Population  2015 Population  \
# Continent     Country
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6
# .الوصول الى البيانات
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#  بالتسمية (Label-based)
#  </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.1 الوصول الى البيانات من خلال تحديد قيمة ضمن صف معين
#  </div>

# %%
df.loc["Africa"]
# Out:
#                           Rank CCA3       Capital       Average  \
# Country
# Algeria                     34  DZA       Algiers  3.157280e+07
# Angola                      42  AGO        Luanda  2.038648e+07
# Benin                       77  BEN    Porto-Novo  8.170413e+06
# Botswana                   144  BWA      Gaborone  1.771602e+06
# Burkina Faso                58  BFA   Ouagadougou  1.407377e+07
# Burundi                     78  BDI     Bujumbura  8.070710e+06
# Cameroon                    53  CMR       Yaounde  1.734889e+07
# Cape Verde                 171  CPV         Praia  4.595596e+05
# Central African Republic   117  CAF        Bangui  3.931573e+06
# Chad                        69  TCD     N'Djamena  1.032061e+07
# Comoros                    163  COM        Moroni  5.709670e+05
# Djibouti                   160  DJI      Djibouti  7.405211e+05
# DR Congo                    15  COD      Kinshasa  5.854698e+07
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.2 الوصول للبيانات وفق الفهرسة المركبة من خلال تحديد عمودين
#  </div>

# %%
df.loc[("Africa", "Algeria")]
# Out:
# Rank                                    34
# CCA3                                   DZA
# Capital                            Algiers
# Average                        31572797.13
# 2022 Population                 44903225.0
# 2020 Population                 43451666.0
# 2015 Population                 39543154.0
# 2010 Population                 35856344.0
# 2000 Population                 30774621.0
# 1990 Population                 25518074.0
# 1980 Population                 18739378.0
# 1970 Population                 13795915.0
# Area (km²)                       2381741.0
# Density (per km²)                  18.8531
# Growth Rate                         1.0164
# World Population Percentage           0.56
# Name: (Africa, Algeria), dtype: object

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.2 الوصول لقيمة محددة وفق الفهرسة المركبة بإستخدام loc من خلال التسمية
#  </div>

# %%
df.loc[("Africa", "Algeria"), "1990 Population"]
# Out:
# np.float64(25518074.0)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.3 الوصول لقيمة محددة وفق الفهرسة المركبة بإستخدام at من خلال التسمية
#  </div>

# %%
df.at[("Africa", "Algeria"), "1990 Population"]
# Out:
# np.float64(25518074.0)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# إعادة الفهرس إلى العمود الإفتراضي مع الإبقاء على الفهرس القديم
#  </div>

# %%
df.reset_index(drop=False, inplace=True)
df.head()
# Out:
#   Continent         Country  Rank CCA3           Capital       Average  \
# 0      Asia     Afghanistan    36  AFG             Kabul  2.444019e+07
# 1    Europe         Albania   138  ALB            Tirana  2.906065e+06
# 2    Africa         Algeria    34  DZA           Algiers  3.157280e+07
# 3   Oceania  American Samoa   213  ASM         Pago Pago  4.533600e+04
# 4    Europe         Andorra   203  AND  Andorra la Vella  5.949075e+04
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0       41128771.0       38972230.0       33753499.0       28189672.0
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# 2       44903225.0       43451666.0       39543154.0       35856344.0
# 3          44273.0          46189.0          51368.0          54849.0
# 4          79824.0          77700.0          71746.0          71519.0
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.4 الوصول الى قيمة محددة من خلال تحديد التسمية باستخدام at
#  </div>

# %%
df.at[2,'Capital']
# Out:
# 'Algiers'

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.5 الوصول الى بيانات صف من خلال الموقع الرقمي للصف
#  </div>

# %%
df.iloc[2]
# Out:
# Continent                           Africa
# Country                            Algeria
# Rank                                    34
# CCA3                                   DZA
# Capital                            Algiers
# Average                        31572797.13
# 2022 Population                 44903225.0
# 2020 Population                 43451666.0
# 2015 Population                 39543154.0
# 2010 Population                 35856344.0
# 2000 Population                 30774621.0
# 1990 Population                 25518074.0
# 1980 Population                 18739378.0
# 1970 Population                 13795915.0
# Area (km²)                       2381741.0
# Density (per km²)                  18.8531
# Growth Rate                         1.0164
# World Population Percentage           0.56
# Name: 2, dtype: object

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.6 الوصول الى قيمة عمود محدد لصف معين وفق الموقع الرقمي
#  </div>

# %%
df.loc[2, 'Growth Rate']
# Out:
# np.float64(1.0164)

# %%
df.loc[2, ['Country', '2022 Population']]
# Out:
# Country               Algeria
# 2022 Population    44903225.0
# Name: 2, dtype: object

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.7 الوصول الى  أكثر من صف وأكثر من عمود من خلال تحديد الموقع الرقمي
#
#
#  </div>

# %%
df.iloc[0:5, 0:4]
# Out:
#   Continent         Country  Rank CCA3
# 0      Asia     Afghanistan    36  AFG
# 1    Europe         Albania   138  ALB
# 2    Africa         Algeria    34  DZA
# 3   Oceania  American Samoa   213  ASM
# 4    Europe         Andorra   203  AND

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 6.8 الوصول الى قيمة محددة من خلال تحديد الموقع الرقمي باستخدام iat
#  </div>

# %%
df.iat[2,4]
# Out:
# 'Algiers'
